# %%
#Import Library
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
#Set up Connection 
client_id = '2567d05fa947471eb0de0a7289d0523f' #Need to create developer profile
client_secret = '78962627338540c5923d70b4fe0044dd'
username = 'esampsel15' #Store username
scope = 'playlist-read-collaborative'
redirect_uri= '52UvYZ2bFuY3JdE4B4x0ZF'
category = 'loudness'

# %%
# Connect To api
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Retrieve ID's for each track

def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

ids = getTrackIDs(username, redirect_uri)

# %%
print(len(ids))
print(ids)
# Out:
# 29
# ['5CaXxLM568tBh1PwhXdciZ', '3woRy7uxzl1lO2XO99oHsN', '1DWZUa5Mzf2BwzpHtgbHPY', '1sMi8ywnrNKysixM34zH9W', '6ABAUBmOyfPtAUU0IpEKJf', '36J0iaPDGbYGsHvYpaYs3k', '1AgSUWSzmza5jF6ER5R68v', '4D1eVq5AUILwjg3tAe7o6M', '3EApebexZ7YqDIqw2EMTDh', '6fTdcGsjxlAD9PSkoPaLMX', '7eqoqGkKwgOaWNNHx90uEZ', '5H0NU2sHWUnWCcZyYlX46X', '7wGoRwE6MZnm9flIMKWPul', '1LywMukB9j93vLrxHIyc6U', '2mvGl0m5Pg87PJzKzssPdi', '0aX2TCQRU3FHUMrOagZi2k', '3LxG9HkMMFP0MZuiw3O2rF', '2A9h3EvZynC0jeiLNcnoWB', '5P4OS6niKRV6zsdPKPcnRM', '02Ygu8lo3qSknRpcBnspso', '6wXgnhpmOPEJ7cUweSyy2B', '4RVbK6cV0VqWdpCDcx3hiT', '7yotKA30dwTKNEGomV9ZsI', '3s7MCdXyWmwjdcWh7GWXas', '3OXpdrHLT4IqM76RajgM6Q', '1FCwkiooaMCY8YpQdSJ0Gc', '3q0U6eqmHObU2cy0O6VHGS', '7iMDaY1LnASwCk2uUpMtii', '5h0Jgt873QtgL6nJRBGfT6']

# %%
#Create a function to cellect metadata for each song

def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop function over every track id
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
#df.to_csv("spotify.csv", sep = ',')

# %%
df['ids'] = ids

# %%
df.head()
# Out:
#                          name                           album  \
# 0                Good Morning                      Graduation
# 1  The Man Who Has Everything      The Man Who Has Everything
# 2                   Good News                         Circles
# 3       La La Land - Acoustic                   La La Land EP
# 4                The Question  Macadelic (Remastered Edition)
#
#               artist release_date  length  popularity  danceability  \
# 0         Kanye West   2007-09-11  195093          71         0.480
# 1  Chance the Rapper   2018-11-30  218624          56         0.686
# 2         Mac Miller   2020-01-17  342040          76         0.794
# 3         Bryce Vine   2019-07-05  137195          61         0.734
# 4         Mac Miller   2012-03-23  371870          61         0.736
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0791         0.480   0.631          0.000105    0.1490    -5.488
# ...

# %%
test = df.sort_values(by=[category], ascending=False)

# %%
test.head()
# Out:
#                                     name  \
# 15                                2 Gone
# 7                              On My Own
# 28  That's Life (feat. Mac Miller & Sia)
# 17                             Washed Up
# 6   THRU THE NIGHT (feat. Bryson Tiller)
#
#                                    album       artist release_date  length  \
# 15                                2 Gone         CVBZ   2018-07-13  190252
# 7                          ERYS (Deluxe)        Jaden   2019-07-05  244720
# 28  That's Life (feat. Mac Miller & Sia)      88-Keys   2019-06-20  202390
# 17                             Washed Up  Cheat Codes   2020-11-04  174916
# 6                               Confetti  Jack Harlow   2019-09-20  128409
#
#     popularity  danceability  acousticness  danceability  energy  \
# 15          56         0.699        0.1410         0.699   0.873
# 7           66         0.344        0.0214         0.344   0.843
# ...

# %%
song_name_list = test["ids"].tolist()

# %%
top_ids = song_name_list[0:5]

# %%
top_ids
# Out:
# ['0aX2TCQRU3FHUMrOagZi2k',
#  '4D1eVq5AUILwjg3tAe7o6M',
#  '5h0Jgt873QtgL6nJRBGfT6',
#  '2A9h3EvZynC0jeiLNcnoWB',
#  '1AgSUWSzmza5jF6ER5R68v']

# %%
x = sp.recommendations(seed_artists=None, seed_genres=None, seed_tracks=top_ids, limit=20, country=None)

# %%
x
# Out:
# {'tracks': [{'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ShZZUjkbXCjhwrb18BA8I'},
#       'href': 'https://api.spotify.com/v1/artists/1ShZZUjkbXCjhwrb18BA8I',
#       'id': '1ShZZUjkbXCjhwrb18BA8I',
#       'name': 'Bryce Vine',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ShZZUjkbXCjhwrb18BA8I'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3KV3p5EY4AvKxOlhGHORLg'},
#       'href': 'https://api.spotify.com/v1/artists/3KV3p5EY4AvKxOlhGHORLg',
#       'id': '3KV3p5EY4AvKxOlhGHORLg',
#       'name': 'Jeremih',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KV3p5EY4AvKxOlhGHORLg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
# ...

# %%
song_recommendation = x['tracks'][0]['name']
song_recommendation
# Out:
# 'Baby Girl (feat. Jeremih)'
